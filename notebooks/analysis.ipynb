# %%
using DataFrames, CSV
using DrWatson

# %%
df = CSV.read(datadir("transaction_table.csv"), DataFrame)
# Out:
# 1056320×20 DataFrame
#      Row │ trans_id  account_id  date        direction  type      amount   bal ⋯
#          │ Int64     Int64       Date        String15   String15  Float64  Flo ⋯
# ─────────┼──────────────────────────────────────────────────────────────────────
#        1 │   695247        2378  1993-01-01  inbound    Cash in     700.0    7 ⋯
#        2 │   171812         576  1993-01-01  inbound    Cash in     900.0    9
#        3 │   207264         704  1993-01-01  inbound    Cash in    1000.0   10
#        4 │  1117247        3818  1993-01-01  inbound    Cash in     600.0    6
#        5 │   579373        1972  1993-01-02  inbound    Cash in     400.0    4 ⋯
#        6 │   771035        2632  1993-01-02  inbound    Cash in    1100.0   11
#        7 │   452728        1539  1993-01-03  inbound    Cash in     600.0    6
#        8 │   725751        2484  1993-01-03  inbound    Cash in    1100.0   11
# ...

# %%
using Plots, StatsPlots

# %%
histogram(log.(1 .+ df.amount), normalized=true)
